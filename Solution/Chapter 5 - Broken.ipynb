# %%
# 5

# Commands
# %matplotlib inline

# Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Setting Plot's Confugrations
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 3)
plt.rcParams['font.family'] = 'sans-serif'

# Reading CSV File(s)
df_weather_2012 = pd.read_csv('../data/weather_2012.csv', index_col='Date/Time').

# %%
# 5.1
# Adding URL Template & Modifying Date & Year  & Downloading The Data & Displaying It
url_template = 'http://climate.weather.gc.ca/prods_servs/cdn_climate_summary_report_e.html?intYear={year}&intMonth={month}&prov=&dataFormat=csv&btnSubmit=Download+data'
url = url_template.format(month=3, year=2012)
df_weather_mar2012 = pd.read_csv(url, skiprows=31, index_col='Clim_ID', parse_dates=True, encoding='latin1')
df_weather_mar2012
# Out:
#                          Stn_Name     Lat     Long Prov    Tm  DwTm    D  \
# Clim_ID
# 1011500                 CHEMAINUS  48.935 -123.742   BC   5.7   0.0  NaN
# 1012040    COWICHAN LAKE FORESTRY  48.824 -124.133   BC   3.7   0.0 -2.2
# 1012055             LAKE COWICHAN  48.829 -124.052   BC   3.5  17.0 -2.7
# 1012475          DISCOVERY ISLAND  48.424 -123.225   BC   6.2   0.0  NaN
# 1012573       DUNCAN KELVIN CREEK  48.735 -123.728   BC   4.6   0.0 -1.7
# 1012710         ESQUIMALT HARBOUR  48.432 -123.439   BC   5.5   0.0  NaN
# 1013051         GANGES MANSELL RD  48.872 -123.498   BC   4.8   0.0  NaN
# 10130MN             GALIANO NORTH  48.985 -123.573   BC   6.9   8.0  NaN
# 1014820                   MALAHAT  48.575 -123.530   BC   3.8   1.0  NaN
# 1015105                 METCHOSIN  48.374 -123.561   BC   NaN   NaN  NaN
# 1015628            NORTH COWICHAN  48.824 -123.718   BC   NaN   NaN  NaN
# 1015630            NORTH COWICHAN  48.824 -123.719   BC   4.9   1.0  NaN
# ...
