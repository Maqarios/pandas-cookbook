# %%
# 1

# Commands
# %matplotlib inline

# Imports
import pandas as pd
import matplotlib.pyplot as plt

# Setting Plot's Confugrations
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)

# %%
# 1.1
# Reading CSV File(s)
df_bikes = pd.read_csv('../data/bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')

# %%
# 1.2
# Selecting A Column
df_bikes['Berri 1']
# Out:
# Date
# 2012-01-01      35
# 2012-01-02      83
# 2012-01-03     135
# 2012-01-04     144
# 2012-01-05     197
# 2012-01-06     146
# 2012-01-07      98
# 2012-01-08      95
# 2012-01-09     244
# 2012-01-10     397
# 2012-01-11     273
# 2012-01-12     157
# 2012-01-13      75
# 2012-01-14      32
# 2012-01-15      54
# 2012-01-16     168
# 2012-01-17     155
# 2012-01-18     139
# 2012-01-19     191
# 2012-01-20     161
# 2012-01-21      53
# 2012-01-22      71
# 2012-01-23     210
# 2012-01-24     299
# 2012-01-25     334
# 2012-01-26     306
# 2012-01-27      91
# 2012-01-28      80
# 2012-01-29      87
# 2012-01-30     219
#               ...
# 2012-10-07    1580
# 2012-10-08    1854
# 2012-10-09    4787
# 2012-10-10    3115
# 2012-10-11    3746
# 2012-10-12    3169
# 2012-10-13    1783
# 2012-10-14     587
# 2012-10-15    3292
# 2012-10-16    3739
# 2012-10-17    4098
# 2012-10-18    4671
# 2012-10-19    1313
# 2012-10-20    2011
# 2012-10-21    1277
# 2012-10-22    3650
# ...

# %%
# 1.3
# Plotting A Column
df_bikes['Berri 1'].plot()
# Plotting The Entire Data Frame & Setting Figure's Size
df_bikes.plot(figsize=(15, 10))

# %%
# 1.4
# Reading CSV File & Plotting Data Frame & Setting Figure's Size In One Line
pd.read_csv('../data/bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date').plot(figsize=(20, 7))
